# %%
from sklearn.naive_bayes import GaussianNB
import pandas as pd

pd.options.display.max_columns = 999

# %%
# the path to our flight + weather combined data set
flights_weather_path = '../data/flights_weather.csv'

# %%
flights_weather_df = pd.read_csv(flights_weather_path)
flights_weather_df.head()
# Out:
#    Unnamed: 0  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 0           0  2015      1    1            4      AS             98
# 1           1  2015      1    1            4      AA           2336
# 2           2  2015      1    1            4      US            840
# 3           3  2015      1    1            4      AA            258
# 4           4  2015      1    1            4      AS            135
#
#   TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0      N407AS            ANC                 SEA                    5
# 1      N3KUAA            LAX                 PBI                   10
# 2      N171US            SFO                 CLT                   20
# 3      N3HYAA            LAX                 MIA                   20
# 4      N527AS            SEA                 ANC                   25
#
#    DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  \
# 0          2354.0            -11.0      21.0        15.0           205.0
# 1             2.0             -8.0      12.0        14.0           280.0
# 2            18.0             -2.0      16.0        34.0           286.0
# 3            15.0             -5.0      15.0        30.0           285.0
# 4            24.0             -1.0      11.0        35.0           235.0
#
#    ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  \
# 0         194.0     169.0      1448      404.0      4.0                430
# 1         279.0     263.0      2330      737.0      4.0                750
# 2         293.0     266.0      2296      800.0     11.0                806
# 3         281.0     258.0      2342      748.0      8.0                805
# 4         215.0     199.0      1448      254.0      5.0                320
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                 NaN
# 1         741.0           -9.0         0          0                 NaN
# 2         811.0            5.0         0          0                 NaN
# 3         756.0           -9.0         0          0                 NaN
# 4         259.0          -21.0         0          0                 NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
# 3               NaN             NaN            NaN                  NaN
# 4               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY        DATE IATA_CODE_x origin_weather_station IATA_CODE_y  \
# 0            NaN  2015-01-01         ANC           702725-26491         SEA
# 1            NaN  2015-01-01         LAX           722950-23174         PBI
# 2            NaN  2015-01-01         SFO           724940-23234         CLT
# 3            NaN  2015-01-01         LAX           722950-23174         MIA
# 4            NaN  2015-01-01         SEA           727930-24233         ANC
#
#   destination_weather_station  OR_TEMP  OR_COUNT_TEMP  OR_DEWP  OR_COUNT_DEWP  \
# 0                727930-24233     35.1           24.0     30.7           24.0
# 1                722030-12844     47.1           24.0     22.5           24.0
# 2                723140-13881     49.5           24.0     30.9           24.0
# 3                722020-12839     47.1           24.0     22.5           24.0
# 4                702725-26491     32.9           24.0     22.2           24.0
#
#    OR_SLP  OR_COUNT_SLP  OR_STP  OR_COUNT_STP  OR_VISIB  OR_COUNT_VISIB  \
# 0  1020.1          14.0  1015.2          24.0       7.5            24.0
# 1  1018.8          24.0  1007.2          24.0      10.0            24.0
# 2  1019.4          24.0  1018.8          24.0      10.0            24.0
# 3  1018.8          24.0  1007.2          24.0      10.0            24.0
# 4  1029.7          24.0  1012.7          24.0      10.0            24.0
#
#    OR_WDSP  OR_COUNT_WDSP  OR_MXSPD  OR_GUST OR_MAX OR_MIN OR_PRCP  OR_SNDP  \
# 0      3.6           24.0       6.0    999.9   43.0   32.0   0.09G    999.9
# 1      5.5           24.0      15.0    999.9   57.0   36.0   0.00G    999.9
# 2      7.8           24.0      15.0    999.9   57.9   39.9   0.00G    999.9
# 3      5.5           24.0      15.0    999.9   57.0   36.0   0.00G    999.9
# 4      4.6           24.0      11.1    999.9   42.1   26.1   0.00G    999.9
#
#    OR_FRSHTT  DES_TEMP  DES_COUNT_TEMP  DES_DEWP  DES_COUNT_DEWP  DES_SLP  \
# 0   110000.0      32.9            24.0      22.2            24.0   1029.7
# 1        0.0      74.1            24.0      69.7            24.0   1021.1
# 2        0.0      38.4            24.0      28.4            24.0   1026.8
# 3        0.0      74.8            24.0      67.8            24.0   1021.3
# 4        0.0      35.1            24.0      30.7            24.0   1020.1
#
#    DES_COUNT_SLP  DES_STP  DES_COUNT_STP  DES_VISIB  DES_COUNT_VISIB  \
# 0           24.0   1012.7           24.0       10.0             24.0
# 1           22.0   1020.5           24.0        9.1             24.0
# 2           24.0    998.5           24.0        9.7             24.0
# 3           24.0   1020.2           24.0        8.9             24.0
# 4           14.0   1015.2           24.0        7.5             24.0
#
#    DES_WDSP  DES_COUNT_WDSP  DES_MXSPD  DES_GUST DES_MAX DES_MIN DES_PRCP  \
# 0       4.6            24.0       11.1     999.9    42.1    26.1    0.00G
# 1       5.5            24.0        9.9     999.9    79.0    70.0    0.33G
# 2       2.3            24.0        7.0     999.9    53.1    26.1    0.00G
# 3       4.1            24.0       11.1     999.9    82.0    70.0    0.00G
# 4       3.6            24.0        6.0     999.9    43.0    32.0    0.09G
#
#    DES_SNDP  DES_FRSHTT
# 0     999.9         0.0
# 1     999.9     10000.0
# 2     999.9         0.0
# 3     999.9         0.0
# 4     999.9    110000.0
