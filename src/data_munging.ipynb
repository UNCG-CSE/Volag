# %%
import math
from decimal import *
import numpy as np # linear algebra
import pandas as pd # read_csv and such
from geopy.distance import vincenty # calculate distance between locations
from io import StringIO # convert strings to buffers or something like that.
import os # for listing files in directory

pd.options.display.max_columns = 999

# %% [markdown]
# ### File paths for data sets

# %%
# the paths to our flight related data sets
airlines_path = '../data/flight_delays_2015/airlines.csv'
airports_path = '../data/flight_delays_2015/airports.csv'
flights_path  = '../data/flight_delays_2015/flights.csv'
# weather related paths
weather_path = '../data/weather/2015.csv'
stations_path  = '../data/weather/stations.csv'
weather_files_path = '../data/weather/station_data/'
weather_merged_path = '../data/weather/weather_merged.csv'

# modified data sets for output
airports_modified_path = '../data/flight_delays_2015/airports_modified.csv'
flights_weather_path = '../data/flight_delays_2015/flights_weather.csv'

# %% [markdown]
# ### Read in the data sets

# %%
# read the airlines in and get a dataframe containing the dataset
# Set low_memory to False so that types can be inferred/converted
airlines_df = pd.read_csv(airlines_path, low_memory=False) 
airlines_df.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
airports_df = pd.read_csv(airports_path, low_memory=False, dtype={'usaf': 'str', 'wban': 'str'})
airports_df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
flights_df = pd.read_csv(flights_path, low_memory=False, dtype={'SCHEDULED_DEPARTURE': 'str', 'DEPARTURE_TIME': 'str', 'WHEELS_OFF': 'str', 'WHEELS_ON': 'str', 'SCHEDULED_ARRIVAL': 'str', 'ARRIVAL_TIME': 'str'})
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0            ANC                 SEA                0005           2354
# 1            LAX                 PBI                0010           0002
# 2            SFO                 CLT                0020           0018
# 3            LAX                 MIA                0020           0015
# 4            SEA                 ANC                0025           0024
#
#    DEPARTURE_DELAY  TAXI_OUT WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0       0015           205.0         194.0
# 1             -8.0      12.0       0014           280.0         279.0
# 2             -2.0      16.0       0034           286.0         293.0
# 3             -5.0      15.0       0030           285.0         281.0
# 4             -1.0      11.0       0035           235.0         215.0
#
#    AIR_TIME  DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 0     169.0      1448      0404      4.0              0430         0408
# 1     263.0      2330      0737      4.0              0750         0741
# 2     266.0      2296      0800     11.0              0806         0811
# 3     258.0      2342      0748      8.0              0805         0756
# 4     199.0      1448      0254      5.0              0320         0259
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN

# %%
stations_df = pd.read_csv(stations_path, low_memory=False, dtype={'usaf': 'str', 'wban': 'str'})
stations_df.head()
# Out:
#      usaf   wban        name country state call  lat  lon  elev     begin  \
# 0  007011  99999  CWOS 07011     NaN   NaN  NaN  NaN  NaN   NaN  20120101
# 1  007025  99999  CWOS 07025     NaN   NaN  NaN  NaN  NaN   NaN  20120127
# 2  007034  99999  CWOS 07034     NaN   NaN  NaN  NaN  NaN   NaN  20121024
# 3  007047  99999  CWOS 07047     NaN   NaN  NaN  NaN  NaN   NaN  20120613
# 4  007059  99999  CWOS 07059     NaN   NaN  NaN  NaN  NaN   NaN  20120314
#
#         end
# 0  20121129
# 1  20120127
# 2  20121106
# 3  20120717
# 4  20120828

# %% [markdown]
# ### Add Date Column To Flights
# Use Year, Month, Day columns to create datetime column that will be used later to match weather data.

# %%
flights_df['DATE'] = pd.to_datetime((flights_df.YEAR*10000+flights_df.MONTH*100+flights_df.DAY).apply(str),format='%Y%m%d')
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0            ANC                 SEA                0005           2354
# 1            LAX                 PBI                0010           0002
# 2            SFO                 CLT                0020           0018
# 3            LAX                 MIA                0020           0015
# 4            SEA                 ANC                0025           0024
#
#    DEPARTURE_DELAY  TAXI_OUT WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0       0015           205.0         194.0
# 1             -8.0      12.0       0014           280.0         279.0
# 2             -2.0      16.0       0034           286.0         293.0
# 3             -5.0      15.0       0030           285.0         281.0
# 4             -1.0      11.0       0035           235.0         215.0
#
#    AIR_TIME  DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 0     169.0      1448      0404      4.0              0430         0408
# 1     263.0      2330      0737      4.0              0750         0741
# 2     266.0      2296      0800     11.0              0806         0811
# 3     258.0      2342      0748      8.0              0805         0756
# 4     199.0      1448      0254      5.0              0320         0259
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#         DATE
# 0 2015-01-01
# 1 2015-01-01
# 2 2015-01-01
# 3 2015-01-01
# 4 2015-01-01

# %% [markdown]
# ### Remove stations that are not in the US or are missing latitude/longitude
# Since we know all our Airports are in the US, this will vastly improve performance on calculations

# %%
stations_df = stations_df[np.isfinite(stations_df['lat'])]
stations_df = stations_df[np.isfinite(stations_df['lon'])]
#stations_df = stations_df[stations_df['country'] == 'US']
stations_df.head()
# Out:
#       usaf   wban           name country state  call     lat     lon  elev  \
# 16  010014  99999     SORSTOKKEN      NO   NaN  ENSO  59.792   5.341  48.8
# 17  010016  99999    RORVIK/RYUM      NO   NaN   NaN  64.850  11.233  14.0
# 18  010017  99999          FRIGG      NO   NaN  ENFR  59.980   2.250  48.0
# 19  010020  99999  VERLEGENHUKEN      NO   NaN   NaN  80.050  16.250   8.0
# 20  010030  99999       HORNSUND      NO   NaN   NaN  77.000  15.500  12.0
#
#        begin       end
# 16  19861120  20170915
# 17  19870116  19910806
# 18  19880320  20050228
# 19  19861109  20170916
# 20  19850601  20170916

# %% [markdown]
# ### Read in weather data for all the stations
# Load all the station files and combine into a single dataframe

# %%
# skip if merged file is already created

# dateparse = lambda x: pd.datetime.strptime(x, '%Y%m%d')

# files = os.listdir(weather_files_path)
# weather_df = pd.read_fwf(weather_files_path + files[0], dtype={'STN---': 'str', 'WBAN': 'str', 'FRSHTT': 'str'}, parse_dates=['YEARMODA'], date_parser=dateparse)

# for i in  range(1, len(files)):
#     temp = pd.read_fwf(weather_files_path + files[i], dtype={'STN---': 'str', 'WBAN': 'str', 'FRSHTT': 'str'}, parse_dates=['YEARMODA'], date_parser=dateparse)
#     weather_df = pd.concat([weather_df, temp])

# weather_df.head()
# Out:
#    STN---   WBAN   YEARMODA  TEMP  Unnamed: 4  DEWP  Unnamed: 6     SLP  \
# 0  483280  99999 2015-01-01  71.7          13  60.0          13  1018.2
# 1  483280  99999 2015-01-02  71.2          15  57.1          15  1017.8
# 2  483280  99999 2015-01-03  71.1          15  57.6          15  1016.7
# 3  483280  99999 2015-01-04  72.9          14  59.7          14  1013.6
# 4  483280  99999 2015-01-05  76.5          15  65.1          15  1010.4
#
#    Unnamed: 8    STP   ...    Unnamed: 12  WDSP  Unnamed: 14  MXSPD   GUST  \
# 0           8  989.9   ...             13   1.5           13    6.0  999.9
# 1           8  989.4   ...             10   1.2           15    5.1  999.9
# 2           8  988.3   ...             15   0.7           15    4.1  999.9
# 3           8  985.5   ...             14   0.5           14    4.1  999.9
# 4           8  982.5   ...             11   0.5           15    2.9  999.9
#
#     MAX    MIN   PRCP   SNDP  FRSHTT
# 0  84.2  59.9*  0.00I  999.9  000000
# 1  85.1  53.6*  0.00I  999.9  000000
# 2  86.0  53.6*  0.00I  999.9  000000
# 3  90.3  55.4*  0.00I  999.9  000000
# 4  91.6  59.0*  0.00I  999.9  000000
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Correct Columns
# Some of the column names were not labled, merge the station and WBAN to create a single identifier, and drop the WBAN

# %%
# skip if merged file is already created

# weather_df = weather_df.rename(columns={'STN---': 'STATION', 'Unnamed: 4': 'COUNT_TEMP', 'Unnamed: 6': 'COUNT_DEWP', 'Unnamed: 8': 'COUNT_SLP', 'Unnamed: 10': 'COUNT_STP', 'Unnamed: 12': 'COUNT_VISIB', 'Unnamed: 14': 'COUNT_WDSP'})
# weather_df['STATION'] = weather_df['STATION'] + '-' + weather_df['WBAN']
# weather_df = weather_df.drop('WBAN', 1)
# weather_df.head()
# Out:
#         STATION   YEARMODA  TEMP  COUNT_TEMP  DEWP  COUNT_DEWP     SLP  \
# 0  483280-99999 2015-01-01  71.7          13  60.0          13  1018.2
# 1  483280-99999 2015-01-02  71.2          15  57.1          15  1017.8
# 2  483280-99999 2015-01-03  71.1          15  57.6          15  1016.7
# 3  483280-99999 2015-01-04  72.9          14  59.7          14  1013.6
# 4  483280-99999 2015-01-05  76.5          15  65.1          15  1010.4
#
#    COUNT_SLP    STP  COUNT_STP   ...    COUNT_VISIB  WDSP  COUNT_WDSP  MXSPD  \
# 0          8  989.9          8   ...             13   1.5          13    6.0
# 1          8  989.4          8   ...             10   1.2          15    5.1
# 2          8  988.3          8   ...             15   0.7          15    4.1
# 3          8  985.5          8   ...             14   0.5          14    4.1
# 4          8  982.5          8   ...             11   0.5          15    2.9
#
#     GUST   MAX    MIN   PRCP   SNDP  FRSHTT
# 0  999.9  84.2  59.9*  0.00I  999.9  000000
# 1  999.9  85.1  53.6*  0.00I  999.9  000000
# 2  999.9  86.0  53.6*  0.00I  999.9  000000
# 3  999.9  90.3  55.4*  0.00I  999.9  000000
# 4  999.9  91.6  59.0*  0.00I  999.9  000000
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Save Dataframe
# Save to a file to keep from having to run again.

# %%
# skip if merged file is already created

# weather_df.to_csv(weather_merged_path)

# %%
# load the file instead if you have merged file
weather_df = pd.read_csv(weather_merged_path, dtype={'STATION': 'str', 'FRSHTT': 'str', }, parse_dates=['YEARMODA'])
weather_df = weather_df.drop('Unnamed: 0', 1)
weather_df.head()
# Out:
#    Unnamed: 0       STATION   YEARMODA  TEMP  COUNT_TEMP  DEWP  COUNT_DEWP  \
# 0           0  483280-99999 2015-01-01  71.7          13  60.0          13
# 1           1  483280-99999 2015-01-02  71.2          15  57.1          15
# 2           2  483280-99999 2015-01-03  71.1          15  57.6          15
# 3           3  483280-99999 2015-01-04  72.9          14  59.7          14
# 4           4  483280-99999 2015-01-05  76.5          15  65.1          15
#
#       SLP  COUNT_SLP    STP  COUNT_STP  VISIB  COUNT_VISIB  WDSP  COUNT_WDSP  \
# 0  1018.2          8  989.9          8    5.4           13   1.5          13
# 1  1017.8          8  989.4          8    5.0           10   1.2          15
# 2  1016.7          8  988.3          8    3.7           15   0.7          15
# 3  1013.6          8  985.5          8    3.4           14   0.5          14
# 4  1010.4          8  982.5          8    4.6           11   0.5          15
#
#    MXSPD   GUST   MAX    MIN   PRCP   SNDP  FRSHTT
# 0    6.0  999.9  84.2  59.9*  0.00I  999.9  000000
# 1    5.1  999.9  85.1  53.6*  0.00I  999.9  000000
# 2    4.1  999.9  86.0  53.6*  0.00I  999.9  000000
# 3    4.1  999.9  90.3  55.4*  0.00I  999.9  000000
# 4    2.9  999.9  91.6  59.0*  0.00I  999.9  000000

# %% [markdown]
# ### Update Stations DataFrame to use same station id as weather data

# %%
stations_df = stations_df.rename(columns={'usaf': 'station'})
stations_df['station'] = stations_df['station'] + '-' + stations_df['wban']
stations_df = stations_df.drop('wban', 1)
stations_df.head()
# Out:
#          station           name country state  call     lat     lon  elev  \
# 16  010014-99999     SORSTOKKEN      NO   NaN  ENSO  59.792   5.341  48.8
# 17  010016-99999    RORVIK/RYUM      NO   NaN   NaN  64.850  11.233  14.0
# 18  010017-99999          FRIGG      NO   NaN  ENFR  59.980   2.250  48.0
# 19  010020-99999  VERLEGENHUKEN      NO   NaN   NaN  80.050  16.250   8.0
# 20  010030-99999       HORNSUND      NO   NaN   NaN  77.000  15.500  12.0
#
#        begin       end
# 16  19861120  20170915
# 17  19870116  19910806
# 18  19880320  20050228
# 19  19861109  20170916
# 20  19850601  20170916

# %% [markdown]
# ### Add Data Counts to Stations
# Update stations_df to also contain how many days of data that each station has.

# %%
station_counts_df = weather_df.groupby(['STATION']).count()[['TEMP']]
station_counts_df = station_counts_df.rename(columns={'TEMP': 'COUNT'})
station_counts_df.head()
# Out:
#               COUNT
# STATION
# 007070-99999      2
# 008411-99999    365
# 008414-99999    364
# 008415-99999     73
# 008416-99999    102

# %%
stations_df = pd.merge(stations_df, station_counts_df, left_on='station', right_index=True, how='inner')
stations_df.head()
# Out:
#          station           name country state  call     lat     lon  elev  \
# 16  010014-99999     SORSTOKKEN      NO   NaN  ENSO  59.792   5.341  48.8
# 19  010020-99999  VERLEGENHUKEN      NO   NaN   NaN  80.050  16.250   8.0
# 20  010030-99999       HORNSUND      NO   NaN   NaN  77.000  15.500  12.0
# 22  010060-99999        EDGEOYA      NO   NaN   NaN  78.250  22.817  14.0
# 23  010080-99999       LONGYEAR      SV   NaN  ENSB  78.246  15.466  26.8
#
#        begin       end  COUNT
# 16  19861120  20170915    301
# 19  19861109  20170916    236
# 20  19850601  20170916    317
# 22  19730101  20170916    292
# 23  19750929  20170916    365

# %% [markdown]
# ### Assign each airport primary and secondary weather stations
# Assign weather station based on closest weather station with data for full year

# %%
useful_stations_df = stations_df[stations_df['COUNT'] == 365]
len(useful_stations_df.station)
# Out:
# 6202

# %%
for index, row in airports_df.iterrows():
    first = useful_stations_df.iloc[0]
    first_dist = vincenty((row['LATITUDE'], row['LONGITUDE']), (first['lat'], first['lon'])).miles
    second = useful_stations_df.iloc[1]
    second_dist = vincenty((row['LATITUDE'], row['LONGITUDE']), (second['lat'], second['lon'])).miles
    if second_dist < first_dist:
        first, first_dist, second, second_dist = second, second_dist, first, first_dist
    for i in range(2, len(useful_stations_df['station'])):
        dist = vincenty((row['LATITUDE'], row['LONGITUDE']), (useful_stations_df.iloc[i]['lat'], useful_stations_df.iloc[i]['lon'])).miles
        if dist < second_dist:
            if dist < first_dist:
                first, first_dist, second, second_dist = useful_stations_df.iloc[i], dist, first, first_dist
            else:
                second, second_dist = useful_stations_df.iloc[i], dist
    airports_df.loc[index, 'weather_station'], airports_df.loc[index, 'weather_station_distance'] = first['station'], first_dist
airports_df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE weather_station  weather_station_distance
# 0  40.65236  -75.44040    725170-14737                  0.431330
# 1  32.41132  -99.68190    722660-13962                  0.022812
# 2  35.04022 -106.60919    723650-23050                  0.405126
# 3  45.44906  -98.42183    726590-14929                  0.599491
# 4  31.53552  -84.19447    722160-13869                  0.043161

# %%
airports_df.sort_values(['weather_station_distance'], ascending=False)
# Out:
#      Unnamed: 0 IATA_CODE                                            AIRPORT  \
# 246         246       PPG   Pago Pago International Airport (Tafuna Airport)
# 137         137       GUM                         Guam International Airport
# 9             9       ADK                                       Adak Airport
# 94           94       DVL                       Devils Lake Regional Airport
# 70           70       CNY                                  Canyonlands Field
# 248         248       PSE                                  Mercedita Airport
# 295         295       STT                              Cyril E. King Airport
# 318         318       WYS                             Westerly State Airport
# 321         321       YUM                         Yuma International Airport
# 102         102       ESC                               Delta County Airport
# 230         230       ORH                         Worcester Regional Airport
# 219         219       MVY                          Martha's Vineyard Airport
# 138         138       HDN       Yampa Valley Airport (Yampa Valley Regional)
# 239         239       PHX           Phoenix Sky Harbor International Airport
# 221         221       OAJ                            Albert J. Ellis Airport
# 79           79       CWA                          Central Wisconsin Airport
# 187         187       LRD                       Laredo International Airport
# 313         313       UST  Northeast Florida Regional Airport (St. August...
# 228         228       ORD               Chicago O'Hare International Airport
# 36           36       BMI  Central Illinois Regional Airport at Bloomingt...
# 85           85       DEN                       Denver International Airport
# 93           93       DTW                       Detroit Metropolitan Airport
# 203         203       MIA                        Miami International Airport
# 232         232       OTZ                        Ralph Wien Memorial Airport
# 242         242       PIH                         Pocatello Regional Airport
# 207         207       MLI                    Quad City International Airport
# 264         264       ROW                   Roswell International Air Center
# 307         307       TUS                       Tucson International Airport
# 217         217       MSY  Louis Armstrong New Orleans International Airport
# 151         151       IAH               George Bush Intercontinental Airport
# ..          ...       ...                                                ...
# 189         189       LWS                  Lewiston-Nez Perce County Airport
# 4             4       ABY                 Southwest Georgia Regional Airport
# 5             5       ACK                         Nantucket Memorial Airport
# 145         145       HRL                       Valley International Airport
# 139         139       HIB  Range Regional Airport (Chisholm-Hibbing Airport)
# 309         309       TWF       Magic Valley Regional Airport (Joslin Field)
# 69           69       CMX                   Houghton County Memorial Airport
# 50           50       BUR       Bob Hope Airport (Hollywood Burbank Airport)
# 315         315       VLD                          Valdosta Regional Airport
# 60           60       CHS    Charleston International Airport/Charleston AFB
# 311         311       TYR                      Tyler Pounds Regional Airport
# 156         156       IMT                                       Ford Airport
# 111         111       FAY                      Fayetteville Regional Airport
# 147         147       HYA                       Barnstable Municipal Airport
# 181         181       LFT                         Lafayette Regional Airport
# 57           57       CEC     Del Norte County Airport (Jack McNamara Field)
# 59           59       CHO                  Charlottesville-Albemarle Airport
# 222         222       OAK                      Oakland International Airport
# 1             1       ABI                           Abilene Regional Airport
# 144         144       HPN                         Westchester County Airport
# 40           40       BPT  Jack Brooks Regional Airport (Southeast Texas ...
# 195         195       MDW               Chicago Midway International Airport
# 259         259       RIC                     Richmond International Airport
# 7             7       ACV                                     Arcata Airport
# 123         123       GGG                        East Texas Regional Airport
# 191         191       MBS                          MBS International Airport
# 41           41       BQK                     Brunswick Golden Isles Airport
# 266         266       RSW            Southwest Florida International Airport
# 25           25       AZO       Kalamazoo/Battle Creek International Airport
# 237         237       PHF    Newport News/Williamsburg International Airport
#
#                         CITY STATE COUNTRY   LATITUDE   LONGITUDE  \
# 246                Pago Pago    AS     USA  14.331020 -170.710530
# 137                    Agana    GU     USA  13.483450 -144.795980
# 9                       Adak    AK     USA  51.877960 -176.646030
# 94               Devils Lake    ND     USA  48.114250  -98.908780
# 70                      Moab    UT     USA  38.754960 -109.754840
# 248                    Ponce    PR     USA  18.008300  -66.563010
# 295         Charlotte Amalie    VI     USA  18.337310  -64.973360
# 318         West Yellowstone    MT     USA  44.688400 -111.117640
# 321                     Yuma    AZ     USA  32.656580 -114.605970
# 102                 Escanaba    MI     USA  45.722670  -87.093730
# 230                Worcester    MA     USA  42.267340  -71.875710
# 219         Marthas Vineyard    MA     USA  41.393030  -70.614330
# 138                   Hayden    CO     USA  40.481180 -107.217660
# 239                  Phoenix    AZ     USA  33.434170 -112.008060
# 221             Jacksonville    NC     USA  34.829160  -77.612140
# 79                   Mosinee    WI     USA  44.777620  -89.666780
# 187                   Laredo    TX     USA  27.543740  -99.461540
# 313            St. Augustine    FL     USA  29.954924  -81.340138
# 228                  Chicago    IL     USA  41.979600  -87.904460
# 36               Bloomington    IL     USA  40.477990  -88.915950
# 85                    Denver    CO     USA  39.858410 -104.667000
# 93                   Detroit    MI     USA  42.212060  -83.348840
# 203                    Miami    FL     USA  25.793250  -80.290560
# 232                 Kotzebue    AK     USA  66.884680 -162.598550
# 242                Pocatello    ID     USA  42.911310 -112.595860
# 207                   Moline    IL     USA  41.448530  -90.507540
# 264                  Roswell    NM     USA  33.301560 -104.530560
# 307                   Tucson    AZ     USA  32.116080 -110.941030
# 217              New Orleans    LA     USA  29.993390  -90.258030
# 151                  Houston    TX     USA  29.980470  -95.339720
# ..                       ...   ...     ...        ...         ...
# 189                 Lewiston    ID     USA  46.374500 -117.015390
# 4                     Albany    GA     USA  31.535520  -84.194470
# 5                  Nantucket    MA     USA  41.253050  -70.060180
# 145                Harlingen    TX     USA  26.228510  -97.654390
# 139                  Hibbing    MN     USA  47.386600  -92.838990
# 309               Twin Falls    ID     USA  42.481800 -114.487740
# 69                   Hancock    MI     USA  47.168420  -88.489060
# 50                   Burbank    CA     USA  34.200620 -118.358500
# 315                 Valdosta    GA     USA  30.782500  -83.276720
# 60                Charleston    SC     USA  32.898650  -80.040510
# 311                    Tyler    TX     USA  32.354140  -95.402390
# 156  Iron Mountain/Kingsford    MI     USA  45.818350  -88.114540
# 111             Fayetteville    NC     USA  34.991470  -78.880000
# 147                  Hyannis    MA     USA  41.669340  -70.280360
# 181                Lafayette    LA     USA  30.205280  -91.987660
# 57             Crescent City    CA     USA  41.780160 -124.236530
# 59           Charlottesville    VA     USA  38.138640  -78.452860
# 222                  Oakland    CA     USA  37.721290 -122.220720
# 1                    Abilene    TX     USA  32.411320  -99.681900
# 144             White Plains    NY     USA  41.066960  -73.707570
# 40      Beaumont/Port Arthur    TX     USA  29.950830  -94.020690
# 195                  Chicago    IL     USA  41.785980  -87.752420
# 259                 Richmond    VA     USA  37.505170  -77.319670
# 7              Arcata/Eureka    CA     USA  40.978120 -124.108620
# 123                 Longview    TX     USA  32.384860  -94.711710
# 191                  Saginaw    MI     USA  43.532910  -84.079650
# 41                 Brunswick    GA     USA  31.259030  -81.466310
# 266                Ft. Myers    FL     USA  26.536170  -81.755170
# 25                 Kalamazoo    MI     USA  42.234880  -85.552060
# 237             Newport News    VA     USA  37.131900  -76.492990
#
#     weather_station  weather_station_distance
# 246    998337-99999                888.943123
# 137    992620-99999                582.508518
# 9      992820-99999                359.698790
# 94     727575-94925                 70.642466
# 70     724760-23066                 70.471628
# 248    785263-11641                 46.576880
# 295    785510-11624                 45.082374
# 318    726664-94173                 35.775073
# 321    999999-53154                 27.269475
# 102    997792-99999                 22.690501
# 230    725107-04780                 20.579991
# 219    725061-14704                 18.438473
# 138    725700-24046                 16.159295
# 239    722789-03192                 14.168566
# 221    723096-93727                 12.869894
# 79     726463-14897                 10.625268
# 187    762863-99999                  9.566375
# 313    994410-99999                  8.116428
# 228    725300-94846                  1.855612
# 36     724397-54831                  1.827011
# 85     725650-03017                  1.817246
# 93     725370-94847                  1.595788
# 203    722020-12839                  1.592952
# 232    701330-26616                  1.543292
# 242    725780-24156                  1.396686
# 207    725440-14923                  1.391441
# 264    722680-23009                  1.378895
# 307    722740-23160                  1.314483
# 217    722310-12916                  1.238720
# 151    722430-12960                  1.216535
# ..              ...                       ...
# 189    727830-24149                  0.045201
# 4      722160-13869                  0.043161
# 5      725060-14756                  0.042844
# 145    722505-12904                  0.042650
# 139    727455-94931                  0.041452
# 309    725866-94178                  0.040249
# 69     727440-14858                  0.040166
# 50     722880-23152                  0.038807
# 315    722166-93845                  0.038259
# 60     722080-13880                  0.037326
# 311    722448-13972                  0.036959
# 156    727437-94893                  0.035557
# 111    723035-93740                  0.032400
# 147    725067-94720                  0.029960
# 181    722405-13976                  0.028032
# 57     725946-24286                  0.026672
# 59     724016-93736                  0.025975
# 222    724930-23230                  0.025205
# 1      722660-13962                  0.022812
# 144    725037-94745                  0.022626
# 40     722410-12917                  0.021975
# 195    725340-14819                  0.021738
# 259    724010-13740                  0.021591
# 7      725945-24283                  0.021529
# 123    722470-03901                  0.019508
# 191    726379-14845                  0.018645
# 41     722136-53883                  0.018463
# 266    722108-12894                  0.015742
# 25     726357-94815                  0.008836
# 237    723086-93741                  0.006918
#
# [322 rows x 10 columns]

# %% [markdown]
# ### Distant Weather Stations
# Some airports don't have a weather stations that are close and have data for the full year (18 that are more than 2 miles away)

# %% [markdown]
# ### Time to Finally Join that Weather Data to the Flights

# %%
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE    ...      \
# 0            ANC                 SEA                0005    ...
# 1            LAX                 PBI                0010    ...
# 2            SFO                 CLT                0020    ...
# 3            LAX                 MIA                0020    ...
# 4            SEA                 ANC                0025    ...
#
#   ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0         -22.0         0          0                 NaN               NaN
# 1          -9.0         0          0                 NaN               NaN
# 2           5.0         0          0                 NaN               NaN
# 3          -9.0         0          0                 NaN               NaN
# 4         -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY WEATHER_DELAY       DATE
# 0             NaN            NaN                  NaN           NaN 2015-01-01
# 1             NaN            NaN                  NaN           NaN 2015-01-01
# 2             NaN            NaN                  NaN           NaN 2015-01-01
# 3             NaN            NaN                  NaN           NaN 2015-01-01
# 4             NaN            NaN                  NaN           NaN 2015-01-01
#
# [5 rows x 32 columns]

# %%
airports_df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE weather_station  weather_station_distance
# 0  40.65236  -75.44040    725170-14737                  0.431330
# 1  32.41132  -99.68190    722660-13962                  0.022812
# 2  35.04022 -106.60919    723650-23050                  0.405126
# 3  45.44906  -98.42183    726590-14929                  0.599491
# 4  31.53552  -84.19447    722160-13869                  0.043161

# %%
weather_df.head()
# Out:
#         STATION   YEARMODA  TEMP  COUNT_TEMP  DEWP  COUNT_DEWP     SLP  \
# 0  483280-99999 2015-01-01  71.7          13  60.0          13  1018.2
# 1  483280-99999 2015-01-02  71.2          15  57.1          15  1017.8
# 2  483280-99999 2015-01-03  71.1          15  57.6          15  1016.7
# 3  483280-99999 2015-01-04  72.9          14  59.7          14  1013.6
# 4  483280-99999 2015-01-05  76.5          15  65.1          15  1010.4
#
#    COUNT_SLP    STP  COUNT_STP   ...    COUNT_VISIB  WDSP  COUNT_WDSP  MXSPD  \
# 0          8  989.9          8   ...             13   1.5          13    6.0
# 1          8  989.4          8   ...             10   1.2          15    5.1
# 2          8  988.3          8   ...             15   0.7          15    4.1
# 3          8  985.5          8   ...             14   0.5          14    4.1
# 4          8  982.5          8   ...             11   0.5          15    2.9
#
#     GUST   MAX    MIN   PRCP   SNDP  FRSHTT
# 0  999.9  84.2  59.9*  0.00I  999.9  000000
# 1  999.9  85.1  53.6*  0.00I  999.9  000000
# 2  999.9  86.0  53.6*  0.00I  999.9  000000
# 3  999.9  90.3  55.4*  0.00I  999.9  000000
# 4  999.9  91.6  59.0*  0.00I  999.9  000000
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Merge stations
# Merge the airports_df on origin and destination airports to get stations for each flight.

# %%
flights_merged_df = pd.merge(flights_df, airports_df[['IATA_CODE', 'weather_station']], left_on='ORIGIN_AIRPORT', right_on='IATA_CODE', how='left')
flights_merged_df = flights_merged_df.rename(columns={'weather_station': 'origin_weather_station'})
flights_merged_df = pd.merge(flights_merged_df, airports_df[['IATA_CODE', 'weather_station']], left_on='DESTINATION_AIRPORT', right_on='IATA_CODE', how='left')
flights_merged_df = flights_merged_df.rename(columns={'weather_station': 'destination_weather_station'})
flights_merged_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0            ANC                 SEA                0005           2354
# 1            LAX                 PBI                0010           0002
# 2            SFO                 CLT                0020           0018
# 3            LAX                 MIA                0020           0015
# 4            SEA                 ANC                0025           0024
#
#    DEPARTURE_DELAY  TAXI_OUT WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0       0015           205.0         194.0
# 1             -8.0      12.0       0014           280.0         279.0
# 2             -2.0      16.0       0034           286.0         293.0
# 3             -5.0      15.0       0030           285.0         281.0
# 4             -1.0      11.0       0035           235.0         215.0
#
#    AIR_TIME  DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 0     169.0      1448      0404      4.0              0430         0408
# 1     263.0      2330      0737      4.0              0750         0741
# 2     266.0      2296      0800     11.0              0806         0811
# 3     258.0      2342      0748      8.0              0805         0756
# 4     199.0      1448      0254      5.0              0320         0259
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#         DATE IATA_CODE_x origin_weather_station IATA_CODE_y  \
# 0 2015-01-01         ANC           702725-26491         SEA
# 1 2015-01-01         LAX           722950-23174         PBI
# 2 2015-01-01         SFO           724940-23234         CLT
# 3 2015-01-01         LAX           722950-23174         MIA
# 4 2015-01-01         SEA           727930-24233         ANC
#
#   destination_weather_station
# 0                727930-24233
# 1                722030-12844
# 2                723140-13881
# 3                722020-12839
# 4                702725-26491

# %% [markdown]
# ### Merge the weather for origin airport
# Merge on matching date and station.

# %%
flights_merged_df = pd.merge(flights_merged_df, weather_df, left_on=['origin_weather_station', 'DATE'], right_on=['STATION', 'YEARMODA'], how='left')
flights_merged_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0            ANC                 SEA                0005           2354
# 1            LAX                 PBI                0010           0002
# 2            SFO                 CLT                0020           0018
# 3            LAX                 MIA                0020           0015
# 4            SEA                 ANC                0025           0024
#
#    DEPARTURE_DELAY  TAXI_OUT WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0       0015           205.0         194.0
# 1             -8.0      12.0       0014           280.0         279.0
# 2             -2.0      16.0       0034           286.0         293.0
# 3             -5.0      15.0       0030           285.0         281.0
# 4             -1.0      11.0       0035           235.0         215.0
#
#    AIR_TIME  DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 0     169.0      1448      0404      4.0              0430         0408
# 1     263.0      2330      0737      4.0              0750         0741
# 2     266.0      2296      0800     11.0              0806         0811
# 3     258.0      2342      0748      8.0              0805         0756
# 4     199.0      1448      0254      5.0              0320         0259
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#         DATE IATA_CODE_x origin_weather_station IATA_CODE_y  \
# 0 2015-01-01         ANC           702725-26491         SEA
# 1 2015-01-01         LAX           722950-23174         PBI
# 2 2015-01-01         SFO           724940-23234         CLT
# 3 2015-01-01         LAX           722950-23174         MIA
# 4 2015-01-01         SEA           727930-24233         ANC
#
#   destination_weather_station       STATION   YEARMODA  TEMP  COUNT_TEMP  \
# 0                727930-24233  702725-26491 2015-01-01  35.1        24.0
# 1                722030-12844  722950-23174 2015-01-01  47.1        24.0
# 2                723140-13881  724940-23234 2015-01-01  49.5        24.0
# 3                722020-12839  722950-23174 2015-01-01  47.1        24.0
# 4                702725-26491  727930-24233 2015-01-01  32.9        24.0
#
#    DEWP  COUNT_DEWP     SLP  COUNT_SLP     STP  COUNT_STP  VISIB  COUNT_VISIB  \
# 0  30.7        24.0  1020.1       14.0  1015.2       24.0    7.5         24.0
# 1  22.5        24.0  1018.8       24.0  1007.2       24.0   10.0         24.0
# 2  30.9        24.0  1019.4       24.0  1018.8       24.0   10.0         24.0
# 3  22.5        24.0  1018.8       24.0  1007.2       24.0   10.0         24.0
# 4  22.2        24.0  1029.7       24.0  1012.7       24.0   10.0         24.0
#
#    WDSP  COUNT_WDSP  MXSPD   GUST   MAX   MIN   PRCP   SNDP  FRSHTT
# 0   3.6        24.0    6.0  999.9  43.0  32.0  0.09G  999.9  110000
# 1   5.5        24.0   15.0  999.9  57.0  36.0  0.00G  999.9  000000
# 2   7.8        24.0   15.0  999.9  57.9  39.9  0.00G  999.9  000000
# 3   5.5        24.0   15.0  999.9  57.0  36.0  0.00G  999.9  000000
# 4   4.6        24.0   11.1  999.9  42.1  26.1  0.00G  999.9  000000

# %% [markdown]
# ### Rename merged columns
# Columns need to be renamed to prevent issues when merging the dataframes again.

# %%
flights_merged_df = flights_merged_df.drop(['STATION', 'YEARMODA'], 1)
flights_merged_df = flights_merged_df.rename(columns={'TEMP': 'OR_TEMP', 'COUNT_TEMP': 'OR_COUNT_TEMP', 'DEWP': 'OR_DEWP', 'COUNT_DEWP': 'OR_COUNT_DEWP', 'SLP': 'OR_SLP', 'COUNT_SLP': 'OR_COUNT_SLP', 'STP': 'OR_STP', 'COUNT_STP': 'OR_COUNT_STP', 'VISIB': 'OR_VISIB', 'COUNT_VISIB': 'OR_COUNT_VISIB', 'WDSP': 'OR_WDSP', 'COUNT_WDSP': 'OR_COUNT_WDSP', 'MXSPD': 'OR_MXSPD', 'GUST': 'OR_GUST', 'MAX': 'OR_MAX', 'MIN': 'OR_MIN', 'PRCP': 'OR_PRCP', 'SNDP': 'OR_SNDP', 'FRSHTT': 'OR_FRSHTT'})

# %% [markdown]
# ### Merge the weather for destination airport
# Merge on matching date and station. Also rename columns to match format of origin weather data

# %%
flights_merged_df = pd.merge(flights_merged_df, weather_df, left_on=['destination_weather_station', 'DATE'], right_on=['STATION', 'YEARMODA'], how='left')
flights_merged_df.head()
flights_merged_df = flights_merged_df.drop(['STATION', 'YEARMODA'], 1)
flights_merged_df = flights_merged_df.rename(columns={'TEMP': 'DES_TEMP', 'COUNT_TEMP': 'DES_COUNT_TEMP', 'DEWP': 'DES_DEWP', 'COUNT_DEWP': 'DES_COUNT_DEWP', 'SLP': 'DES_SLP', 'COUNT_SLP': 'DES_COUNT_SLP', 'STP': 'DES_STP', 'COUNT_STP': 'DES_COUNT_STP', 'VISIB': 'DES_VISIB', 'COUNT_VISIB': 'DES_COUNT_VISIB', 'WDSP': 'DES_WDSP', 'COUNT_WDSP': 'DES_COUNT_WDSP', 'MXSPD': 'DES_MXSPD', 'GUST': 'DES_GUST', 'MAX': 'DES_MAX', 'MIN': 'DES_MIN', 'PRCP': 'DES_PRCP', 'SNDP': 'DES_SNDP', 'FRSHTT': 'DES_FRSHTT'})
flights_merged_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0            ANC                 SEA                0005           2354
# 1            LAX                 PBI                0010           0002
# 2            SFO                 CLT                0020           0018
# 3            LAX                 MIA                0020           0015
# 4            SEA                 ANC                0025           0024
#
#    DEPARTURE_DELAY  TAXI_OUT WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0       0015           205.0         194.0
# 1             -8.0      12.0       0014           280.0         279.0
# 2             -2.0      16.0       0034           286.0         293.0
# 3             -5.0      15.0       0030           285.0         281.0
# 4             -1.0      11.0       0035           235.0         215.0
#
#    AIR_TIME  DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 0     169.0      1448      0404      4.0              0430         0408
# 1     263.0      2330      0737      4.0              0750         0741
# 2     266.0      2296      0800     11.0              0806         0811
# 3     258.0      2342      0748      8.0              0805         0756
# 4     199.0      1448      0254      5.0              0320         0259
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#         DATE IATA_CODE_x origin_weather_station IATA_CODE_y  \
# 0 2015-01-01         ANC           702725-26491         SEA
# 1 2015-01-01         LAX           722950-23174         PBI
# 2 2015-01-01         SFO           724940-23234         CLT
# 3 2015-01-01         LAX           722950-23174         MIA
# 4 2015-01-01         SEA           727930-24233         ANC
#
#   destination_weather_station  OR_TEMP  OR_COUNT_TEMP  OR_DEWP  OR_COUNT_DEWP  \
# 0                727930-24233     35.1           24.0     30.7           24.0
# 1                722030-12844     47.1           24.0     22.5           24.0
# 2                723140-13881     49.5           24.0     30.9           24.0
# 3                722020-12839     47.1           24.0     22.5           24.0
# 4                702725-26491     32.9           24.0     22.2           24.0
#
#    OR_SLP  OR_COUNT_SLP  OR_STP  OR_COUNT_STP  OR_VISIB  OR_COUNT_VISIB  \
# 0  1020.1          14.0  1015.2          24.0       7.5            24.0
# 1  1018.8          24.0  1007.2          24.0      10.0            24.0
# 2  1019.4          24.0  1018.8          24.0      10.0            24.0
# 3  1018.8          24.0  1007.2          24.0      10.0            24.0
# 4  1029.7          24.0  1012.7          24.0      10.0            24.0
#
#    OR_WDSP  OR_COUNT_WDSP  OR_MXSPD  OR_GUST OR_MAX OR_MIN OR_PRCP  OR_SNDP  \
# 0      3.6           24.0       6.0    999.9   43.0   32.0   0.09G    999.9
# 1      5.5           24.0      15.0    999.9   57.0   36.0   0.00G    999.9
# 2      7.8           24.0      15.0    999.9   57.9   39.9   0.00G    999.9
# 3      5.5           24.0      15.0    999.9   57.0   36.0   0.00G    999.9
# 4      4.6           24.0      11.1    999.9   42.1   26.1   0.00G    999.9
#
#   OR_FRSHTT  DES_TEMP  DES_COUNT_TEMP  DES_DEWP  DES_COUNT_DEWP  DES_SLP  \
# 0    110000      32.9            24.0      22.2            24.0   1029.7
# 1    000000      74.1            24.0      69.7            24.0   1021.1
# 2    000000      38.4            24.0      28.4            24.0   1026.8
# 3    000000      74.8            24.0      67.8            24.0   1021.3
# 4    000000      35.1            24.0      30.7            24.0   1020.1
#
#    DES_COUNT_SLP  DES_STP  DES_COUNT_STP  DES_VISIB  DES_COUNT_VISIB  \
# 0           24.0   1012.7           24.0       10.0             24.0
# 1           22.0   1020.5           24.0        9.1             24.0
# 2           24.0    998.5           24.0        9.7             24.0
# 3           24.0   1020.2           24.0        8.9             24.0
# 4           14.0   1015.2           24.0        7.5             24.0
#
#    DES_WDSP  DES_COUNT_WDSP  DES_MXSPD  DES_GUST DES_MAX DES_MIN DES_PRCP  \
# 0       4.6            24.0       11.1     999.9    42.1    26.1    0.00G
# 1       5.5            24.0        9.9     999.9    79.0    70.0    0.33G
# 2       2.3            24.0        7.0     999.9    53.1    26.1    0.00G
# 3       4.1            24.0       11.1     999.9    82.0    70.0    0.00G
# 4       3.6            24.0        6.0     999.9    43.0    32.0    0.09G
#
#    DES_SNDP DES_FRSHTT
# 0     999.9     000000
# 1     999.9     010000
# 2     999.9     000000
# 3     999.9     000000
# 4     999.9     110000

# %% [markdown]
# ### Save merged data

# %%
flights_merged_df.to_csv(flights_weather_path)
